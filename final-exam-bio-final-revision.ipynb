# %% [markdown]
# <div style="text-align: right">CSCI E-7 Introduction to Python Programming for Life Sciences</div>
# <div style="text-align: right">Dino Konstantopoulos, **Final Exam, Take Home Portion**</div>
#
# # *Working at Google - good idea?*
#
#
# ### You meet Sergey Brin
#
# You've been hired at Google to run their **Life Sciences division**, congratulations! On your first day after your move to California's Silicon Valley, **Sergey Brin** comes in to meet the new wizard pythonista. He gets talking and admits to you there's so many googlers that he just cannot keep track of all of them. But he would like to build a rolodex of **central** googlers. Not just central in terms of titles or degrees or awards, but central in terms of social connections. Sergey wants you to find out who the most *social* googlers are.
#
# <br />
# <center>
# <img src = data:image/jpeg;base64,... width = 400 />
# </center>
#
# Sergey has an idea: He gives you a list of projects that googlers have worked on, a list of Cruises googlers have gone on together, and a list of sport clubs users belong to.
#
# You get 3 excel files: `gprojects` are the projects googlers have worked on. The first column is the name of google employees, the subsequent columns are the projects that they have worked on. Googlers love codes, so the projects are encoded as sentences of ***four*** words each. The sentences don't need to make sense. `gcruises` are the cruises that googlers have gone on. each row has the name of the google employee in the first column, and then the cruises she has been on. Cruises are encoded as sentences of ***three*** words each. `gsports` are the sport clubs that googlers belong to. The first column contains googler employee name, subsequent columns the sport clubs they belong to. Sport clubs are encoded as ***two*** words.
#
# Ok, so now you have list of googlers and projects, cruises, and sports in common. You may assume that if any two googlers have worked on the same project, gone on the same cruise, or played the same sport, they are ***connected***. In other words, acquainted with each other.
#
# Sergey Brin tells you he'll be back in a few hours to check on your work. You think to yourself *great, he's testing me* :-(. Fresh from your python class at Harvard Extension, you open the lid of your laptop, fire up a jupyter notebook, and dive in!
#
# This is what Sergey Brin is asking you to figure out:
#
#
# **Part 1.**
#
# 1. a) Read in the three excel files provided as panda dataframes. Hint: you might need to install the xlrd package to get excel support. List Ian Isla's projects, cruises, and sport clubs at Google. Find *one* google employee that is connected with Isla because he or she has been on the same project, cruise, or sport club. **(10 points)**
#
#    b) Find the total number of connections at Google. We define connections as pairs of googlers that worked on a project together, had a cruise together or participated in a sports club together. For example, if Ian Isla and Kaleb Lauren went on a cruise together, then (Ian Isla, Kaleb Lauren) represents a connection. Similarly, if Kaleb Lauren and Roman Valentina played a sport together, then (Kaleb Lauren, Roman Valentina) represents a connection. Furthermore, if Ian Isla and Kaleb Lauren worked on a project together, they have another connection as well. Thus, we have another (Ian Isla, Kaleb Lauren) connection. For this problem, it might help to assign ID's to all your google employees and then loop through projects, cruises and sports to find all possible connections. **(15 points)**
#
#    c) Create a connections dictionary where for each googler, we store a list of all connections they participate in. Using this dictionary, determine the average number of connections per googler. **(15 points)**
#
#    d) Make use of this dictionary to find the most connected googler. What about the 10 *most* connected googlers? What about the 10 *least* connected googlers? What's the total number of connections, and the average number of connections at Google? Note that connections only counts number of projects, cruises, or sports in common. Who one is connected to makes no difference. A connection to Sergey Brin himself counts the same as a connection to a student co-op. **(10 points)**
#
#    Now, what if having important connections is of significance? In other words, being connected to Sergey Brin makes a huge difference: if a googler acquaintance you are connected to is *very* connected, that automatically makes you very ***central*** to google. To answer these questions, we need our old friend PageRank.
#
#    e) One possible way to tap into PageRank is to use the now-familiar package `networkx`. We want you to create a graph from our connections dictionary. Hint: There are many ways of doing this. One possible way involves hooking into the networkx method `parse_adjlist` that takes in an adjacency list(connections). Look up documentation on this function to learn more. **(10 points)**
#
#    f) Use the template from the midterm and previous assignments, or just use networkx's `pagerank()` API that professor mentionned in class to calculate pageRank for google employees. Using this information, find the 10 most central googlers, and the 10 least central googlers. Are they the same as the 10 most and 10 least connected googlers? **(10 points)**
#
#    g) BONUS: Can you plot google's connectome? That connectome should easily reveal the least central googlers, since they represent isolated nodes, far away from network traffic. You have some latitude on how you choose to do this. Can you do something to upend that graph to also easily reveal the most central googlers? **(5 points)**
#
#
#
# ### You meet Larry Page
#
# While you’re pondering, Larry Page comes by your desk. He says wants to see even more connected googlers, and asks you to design a googler-you-may-know recommendation engine.
#
# <br />
# <center>
# <img src = https://specials-images.forbesimg.com/imageserve/5c76bcaaa7ea43100043c836/416x416.jpg?background=000000&cropX1=387&cropX2=1729&cropY1=118&cropY2=1460 width = 300 />
# </center>
#
# You think to yourself that... just maybe googlers might be otherwise (undocumentedly) connected with connections of their connections (outside of projects, cruises, and sports clubs)! So you decide to write some python to assemble connections of connections.
#
# **Part 2.**
#
# 2. a) Write a list comprehension (ideally) or some type of loop to determine connections of connections. Essentially, you should already have a list of connections, but now search the connections of a specific googler to find connections of connections. For example, if (Ian Isla, Kaleb Lauren) were connected in Part 1, and (Kalen Lauren, Roman Valentina) were also connected, then Roman Valentina would be a "connection of a connection" of Ian Isla. While you do this, perform a check to ensure that the connection of a connection should not already be a connection itself. **(20 points)**
#
#     b) What's the average number of connections-of-connections at google? You will be surprised to find out that even with only 3,000 employees, and just a few projects, cruises, and sports in common, the number of connections$^2$ is huge. So, it would take forever to iterate through all possible employees. DON'T DO THIS. Instead, just use a random sampling technique to *sample* through a fraction of employees, throw in some debugging print statements in your loop(s) to see how fast your sampling is progressing, produce a few random samplings and average over these samplings. We leave it up to you how many samples you decide to choose, and will be lenient with our grading as long as your procedure seems reasonable. **(10 points)**
#
#     c) BONUS: What's the average distance that separates any two googlers? You may want to read [this](http://blogs.cornell.edu/info2040/2011/09/26/networks-in-hollywood-the-six-degrees-of-kevin-bacon/) article about Kevin Bacon. [This](https://en.wikipedia.org/wiki/Erd%C5%91s%E2%80%93Bacon_number) is a funny article, too. **(5 points)**
#
# Congratulations! A successful first day at Google! You've made both Sergei and Larry happy. You're on your way to the top of the ladder! Exhausted, you escape from your desk before any other VP of soemthing can ask anything else from you, and stop for some sushi and a little jug of warm sake. Tomorrow is new employee orientation, and you're looking forward to introduce yourself to the most connected googlers. Now *that's* taking advantage of insider information!

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /anaconda3/lib/python3.7/site-packages (1.2.0)

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

gc = pd.read_excel('gcruises.xlsx', sheet_name='Sheet1')
gp = pd.read_excel('gprojects.xlsx', sheet_name='Sheet1')
gs = pd.read_excel('gsports.xlsx', sheet_name='Sheet1')

print("Column headings:")
print(df.columns)
# Out:
# Column headings:
# Index(['Unnamed: 0', 0, 1, 2, 3, 4], dtype='object')

# %%
pd.DataFrame(gc)
# Out:
#                Unnamed: 0                          0  \
# 0                Ian Isla                        NaN
# 1           Julian Isabel                and me door
# 2         Roman Valentina             me Another she
# 3              Diego Lyla          gray the boulders
# 4            Kaleb Lauren               your To gray
# 5              Bryce Isla  encounter: between chosen
# 6        Christian Alaina              maybe her you
# 7           Jonah Destiny                        NaN
# 8           Joseph Summer              better you is
# 9           Emmett Aurora                you the are
# 10         Eric Annabelle             Heizerem of of
# 11         Cole Stephanie              be towards am
# 12           Kevin Melody             over small and
# 13             Silas Ella               poems the my
# 14         Jackson Gianna                  is is the
# 15          Thomas Peyton               the that out
# 16           Owen Adriana             was intend you
# 17             Jake Ariel                        NaN
# 18              Luke Mary              chosen or and
# 19          Elijah Rachel           Surely dawn When
# 20          Jake Scarlett           then over chosen
# 21       Timothy Mckenzie             of there Maybe
# 22           Victor Kylee              she then lean
# 23          Richard Avery               be the front
# 24       George Annabelle                        NaN
# 25             Colton Ava               me closer of
# 26          Angel Addison                the are the
# 27           Jake Arianna                for an gray
# 28               Leo Ruby                  it the is
# 29           Luke Kennedy              foggy lean be
# ...                   ...                        ...
# 2844       Benjamin Grace    cluster explaining your
# 2845         Mateo Payton  imagination foggy bangles
# 2846          Xavier Lily                 and of far
# 2847         Bryan Evelyn        new no conventional
# 2848       Ryker Julianna             small in plant
# 2849     Christian Claire                        NaN
# 2850        Hayden Taylor       accuracy set opening
# 2851         Elias Aubrey         of of conventional
# 2852        Joel Savannah        new no conventional
# 2853         Dominic Lily                and told to
# 2854      Jayce Charlotte                        NaN
# 2855       Vincent Bailey               it poems the
# 2856     Gabriel Izabella                the are the
# 2857          Abel Hayden        The When addressing
# 2858     Greyson Makenzie                        NaN
# 2859        Declan Brooke                the are the
# 2860      Joseph Isabelle             about brush of
# 2861       Wyatt Izabella              only at takes
# 2862         Abel Valeria             is is boulders
# 2863  Christian Elizabeth              there the You
# 2864    Benjamin Savannah                        NaN
# 2865   Santiago Alexandra            and between new
# 2866     Bradley Madeline                        NaN
# 2867         Aidan Willow           Surely dawn When
# 2868          Kaden Julia                        NaN
# 2869           Aidan Ella                  the to to
# 2870      Angel Annabelle  encounter: between chosen
# 2871          Eric Summer                in are lean
# 2872    Zachary Stephanie               be the front
# 2873           Josiah Mya              plant one she
#
#                                  1                         2  \
# 0                              NaN                       NaN
# 1                     front on the            lean words but
# 2                              NaN                       NaN
# 3                gray the boulders              front on the
# 4                  the place rooms         image her falling
# 5                              NaN                       NaN
# 6                    may chosen no             of there door
# 7                              NaN                       NaN
# 8                              NaN                       NaN
# 9                       it in into   urgency emtheem emtheem
# 10                             NaN                       NaN
# 11                       you in of         gray the boulders
# 12                       it is own                       NaN
# 13          always writing urgency                       NaN
# 14                    where to for          then over chosen
# 15                       the it of              you tea then
# 16                     and me door             chosen or and
# 17                             NaN                       NaN
# 18                    poems the my           the seems there
# 19                             NaN                       NaN
# 20                      that be my              where to for
# 21                   to warren one                 the to to
# 22                     of of place            is is boulders
# 23                in range emtheem        of between teacher
# 24                             NaN                       NaN
# 25                   poems in will                       NaN
# 26                             NaN                       NaN
# 27                   to When brush           the place rooms
# 28                 between the the   cluster explaining your
# 29        pleasure was imagination                       NaN
# ...                            ...                       ...
# 2844                     it the is               of The lean
# 2845  surprise radiant imagination             use maybe The
# 2846           instead idleness to                       NaN
# 2847                 plant one she                 out of of
# 2848                           NaN                       NaN
# 2849                           NaN                       NaN
# 2850              the between what  pleasure was imagination
# 2851                     you in of                       NaN
# 2852           instead idleness to    the instead addressing
# 2853                 chosen or and           of the language
# 2854                           NaN                       NaN
# 2855                  of are seems             only at takes
# 2856              her the boulders                my of dawn
# 2857       urgency emtheem emtheem              poems the my
# 2858                           NaN                       NaN
# 2859                           NaN                       NaN
# 2860                  place on set  always accuracy wordless
# 2861              between image of            Heizerem of of
# 2862                           NaN                       NaN
# 2863                are music your          then over chosen
# 2864                           NaN                       NaN
# 2865                  you tea then                       NaN
# 2866                           NaN                       NaN
# 2867             emThisem was from                       NaN
# 2868                           NaN                       NaN
# 2869          house use explaining               it house of
# 2870              roses brush When                       NaN
# 2871                           NaN                       NaN
# 2872               emtheem be then              your To gray
# 2873              em—after the the              your To gray
#
#                              3                       4
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                   may of and     instead idleness to
# 4             then over chosen  the instead addressing
# 5                          NaN                     NaN
# 6              the seems there    accuracy set opening
# 7                          NaN                     NaN
# 8                          NaN                     NaN
# 9              accuracy is the               it the is
# 10                         NaN                     NaN
# 11                         NaN                     NaN
# 12                         NaN                     NaN
# 13                         NaN                     NaN
# 14             where takes the                     NaN
# 15          plant accuracy you                     NaN
# 16      The remembering warren         the intimate in
# 17                         NaN                     NaN
# 18               of there door                     NaN
# 19                         NaN                     NaN
# 20                         NaN                     NaN
# 21     urgency emtheem emtheem                     NaN
# 22              are music your             of The lean
# 23    always accuracy wordless            me closer of
# 24                         NaN                     NaN
# 25                         NaN                     NaN
# 26                         NaN                     NaN
# 27             accuracy is the                     NaN
# 28             the intimate in       pleasure or place
# 29                         NaN                     NaN
# ...                        ...                     ...
# 2844             be towards am                     NaN
# 2845                       NaN                     NaN
# 2846                       NaN                     NaN
# 2847                       NaN                     NaN
# 2848                       NaN                     NaN
# 2849                       NaN                     NaN
# 2850       your and encounter:                     NaN
# 2851                       NaN                     NaN
# 2852                       NaN                     NaN
# 2853             plant one she              one the on
# 2854                       NaN                     NaN
# 2855               that you to                     NaN
# 2856        the where describe                     NaN
# 2857         gray the boulders                     NaN
# 2858                       NaN                     NaN
# 2859                       NaN                     NaN
# 2860     language intimate joy                     NaN
# 2861             may chosen no                     NaN
# 2862                       NaN                     NaN
# 2863                it in into              my of dawn
# 2864                       NaN                     NaN
# 2865                       NaN                     NaN
# 2866                       NaN                     NaN
# 2867                       NaN                     NaN
# 2868                       NaN                     NaN
# 2869           and between new                     NaN
# 2870                       NaN                     NaN
# 2871                       NaN                     NaN
# 2872           Another she the         where takes the
# 2873                       NaN                     NaN
#
# [2874 rows x 6 columns]

# %%
gc2 = gc.loc[:10,:]
gc2
# Out:
#           Unnamed: 0                          0                  1  \
# 0           Ian Isla                        NaN                NaN
# 1      Julian Isabel                and me door       front on the
# 2    Roman Valentina             me Another she                NaN
# 3         Diego Lyla          gray the boulders  gray the boulders
# 4       Kaleb Lauren               your To gray    the place rooms
# 5         Bryce Isla  encounter: between chosen                NaN
# 6   Christian Alaina              maybe her you      may chosen no
# 7      Jonah Destiny                        NaN                NaN
# 8      Joseph Summer              better you is                NaN
# 9      Emmett Aurora                you the are         it in into
# 10    Eric Annabelle             Heizerem of of                NaN
#
#                           2                 3                       4
# 0                       NaN               NaN                     NaN
# 1            lean words but               NaN                     NaN
# 2                       NaN               NaN                     NaN
# 3              front on the        may of and     instead idleness to
# 4         image her falling  then over chosen  the instead addressing
# 5                       NaN               NaN                     NaN
# 6             of there door   the seems there    accuracy set opening
# 7                       NaN               NaN                     NaN
# 8                       NaN               NaN                     NaN
# 9   urgency emtheem emtheem   accuracy is the               it the is
# 10                      NaN               NaN                     NaN

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(10, 2), columns=list('ab'))
df
# Out:
#           a         b
# 0  1.166681 -1.743862
# 1  0.189852 -1.393299
# 2  0.930890 -0.334742
# 3 -0.487821 -0.071970
# 4 -0.510356  0.962036
# 5 -0.621839  0.602396
# 6 -0.385270 -0.137698
# 7  0.551050  1.350282
# 8 -1.173342 -2.857864
# 9 -0.934755 -0.072136

# %%
df.shape[0]
# Out:
# 10

# %%
row = gc.loc[0]
row
array = row.to_numpy(dtype=object)
array
array[1]
# Out:
# nan

# %%
for label, content in gc.iteritems():
   
    print('Label:', label, sep='\n')
    print('content:', content, sep='\n')
# Out:
# content:
# ('Unnamed: 0', 0                  Ian Isla
# 1             Julian Isabel
# 2           Roman Valentina
# 3                Diego Lyla
# 4              Kaleb Lauren
# 5                Bryce Isla
# 6          Christian Alaina
# 7             Jonah Destiny
# 8             Joseph Summer
# 9             Emmett Aurora
# 10           Eric Annabelle
# 11           Cole Stephanie
# 12             Kevin Melody
# 13               Silas Ella
# 14           Jackson Gianna
# 15            Thomas Peyton
# 16             Owen Adriana
# 17               Jake Ariel
# 18                Luke Mary
# 19            Elijah Rachel
# 20            Jake Scarlett
# 21         Timothy Mckenzie
# 22             Victor Kylee
# 23            Richard Avery
# 24         George Annabelle
# 25               Colton Ava
# 26            Angel Addison
# 27             Jake Arianna
# 28                 Leo Ruby
# 29             Luke Kennedy
#                ...
# 2844         Benjamin Grace
# 2845           Mateo Payton
# 2846            Xavier Lily
# 2847           Bryan Evelyn
# 2848         Ryker Julianna
# 2849       Christian Claire
# 2850          Hayden Taylor
# 2851           Elias Aubrey
# 2852          Joel Savannah
# 2853           Dominic Lily
# 2854        Jayce Charlotte
# 2855         Vincent Bailey
# 2856       Gabriel Izabella
# 2857            Abel Hayden
# 2858       Greyson Makenzie
# 2859          Declan Brooke
# 2860        Joseph Isabelle
# 2861         Wyatt Izabella
# 2862           Abel Valeria
# 2863    Christian Elizabeth
# 2864      Benjamin Savannah
# 2865     Santiago Alexandra
# 2866       Bradley Madeline
# 2867           Aidan Willow
# 2868            Kaden Julia
# 2869             Aidan Ella
# 2870        Angel Annabelle
# 2871            Eric Summer
# 2872      Zachary Stephanie
# 2873             Josiah Mya
# Name: Unnamed: 0, Length: 2874, dtype: object)
# content:
# (0, 0                             NaN
# 1                     and me door
# 2                  me Another she
# 3               gray the boulders
# 4                    your To gray
# 5       encounter: between chosen
# 6                   maybe her you
# 7                             NaN
# 8                   better you is
# 9                     you the are
# 10                 Heizerem of of
# 11                  be towards am
# 12                 over small and
# 13                   poems the my
# 14                      is is the
# 15                   the that out
# 16                 was intend you
# 17                            NaN
# 18                  chosen or and
# 19               Surely dawn When
# 20               then over chosen
# 21                 of there Maybe
# 22                  she then lean
# 23                   be the front
# 24                            NaN
# 25                   me closer of
# 26                    the are the
# 27                    for an gray
# 28                      it the is
# 29                  foggy lean be
#                   ...
# 2844      cluster explaining your
# 2845    imagination foggy bangles
# 2846                   and of far
# 2847          new no conventional
# 2848               small in plant
# 2849                          NaN
# 2850         accuracy set opening
# 2851           of of conventional
# 2852          new no conventional
# 2853                  and told to
# 2854                          NaN
# 2855                 it poems the
# 2856                  the are the
# 2857          The When addressing
# 2858                          NaN
# 2859                  the are the
# 2860               about brush of
# 2861                only at takes
# 2862               is is boulders
# 2863                there the You
# 2864                          NaN
# 2865              and between new
# 2866                          NaN
# 2867             Surely dawn When
# 2868                          NaN
# 2869                    the to to
# 2870    encounter: between chosen
# 2871                  in are lean
# 2872                 be the front
# 2873                plant one she
# Name: 0, Length: 2874, dtype: object)
# content:
# (1, 0                                NaN
# 1                       front on the
# 2                                NaN
# 3                  gray the boulders
# 4                    the place rooms
# 5                                NaN
# 6                      may chosen no
# 7                                NaN
# 8                                NaN
# 9                         it in into
# 10                               NaN
# 11                         you in of
# 12                         it is own
# 13            always writing urgency
# 14                      where to for
# 15                         the it of
# 16                       and me door
# 17                               NaN
# 18                      poems the my
# 19                               NaN
# 20                        that be my
# 21                     to warren one
# 22                       of of place
# 23                  in range emtheem
# 24                               NaN
# 25                     poems in will
# 26                               NaN
# 27                     to When brush
# 28                   between the the
# 29          pleasure was imagination
#                     ...
# 2844                       it the is
# 2845    surprise radiant imagination
# 2846             instead idleness to
# 2847                   plant one she
# 2848                             NaN
# 2849                             NaN
# 2850                the between what
# 2851                       you in of
# 2852             instead idleness to
# 2853                   chosen or and
# 2854                             NaN
# 2855                    of are seems
# 2856                her the boulders
# 2857         urgency emtheem emtheem
# 2858                             NaN
# 2859                             NaN
# 2860                    place on set
# 2861                between image of
# 2862                             NaN
# 2863                  are music your
# 2864                             NaN
# 2865                    you tea then
# 2866                             NaN
# 2867               emThisem was from
# 2868                             NaN
# 2869            house use explaining
# 2870                roses brush When
# 2871                             NaN
# 2872                 emtheem be then
# 2873                em—after the the
# Name: 1, Length: 2874, dtype: object)
# content:
# (2, 0                            NaN
# 1                 lean words but
# 2                            NaN
# 3                   front on the
# 4              image her falling
# 5                            NaN
# 6                  of there door
# 7                            NaN
# 8                            NaN
# 9        urgency emtheem emtheem
# 10                           NaN
# 11             gray the boulders
# 12                           NaN
# 13                           NaN
# 14              then over chosen
# 15                  you tea then
# 16                 chosen or and
# 17                           NaN
# 18               the seems there
# 19                           NaN
# 20                  where to for
# 21                     the to to
# 22                is is boulders
# 23            of between teacher
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27               the place rooms
# 28       cluster explaining your
# 29                           NaN
#                   ...
# 2844                 of The lean
# 2845               use maybe The
# 2846                         NaN
# 2847                   out of of
# 2848                         NaN
# 2849                         NaN
# 2850    pleasure was imagination
# 2851                         NaN
# 2852      the instead addressing
# 2853             of the language
# 2854                         NaN
# 2855               only at takes
# 2856                  my of dawn
# 2857                poems the my
# 2858                         NaN
# 2859                         NaN
# 2860    always accuracy wordless
# 2861              Heizerem of of
# 2862                         NaN
# 2863            then over chosen
# 2864                         NaN
# 2865                         NaN
# 2866                         NaN
# 2867                         NaN
# 2868                         NaN
# 2869                 it house of
# 2870                         NaN
# 2871                         NaN
# 2872                your To gray
# 2873                your To gray
# Name: 2, Length: 2874, dtype: object)
# content:
# (3, 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                     may of and
# 4               then over chosen
# 5                            NaN
# 6                the seems there
# 7                            NaN
# 8                            NaN
# 9                accuracy is the
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14               where takes the
# 15            plant accuracy you
# 16        The remembering warren
# 17                           NaN
# 18                 of there door
# 19                           NaN
# 20                           NaN
# 21       urgency emtheem emtheem
# 22                are music your
# 23      always accuracy wordless
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27               accuracy is the
# 28               the intimate in
# 29                           NaN
#                   ...
# 2844               be towards am
# 2845                         NaN
# 2846                         NaN
# 2847                         NaN
# 2848                         NaN
# 2849                         NaN
# 2850         your and encounter:
# 2851                         NaN
# 2852                         NaN
# 2853               plant one she
# 2854                         NaN
# 2855                 that you to
# 2856          the where describe
# 2857           gray the boulders
# 2858                         NaN
# 2859                         NaN
# 2860       language intimate joy
# 2861               may chosen no
# 2862                         NaN
# 2863                  it in into
# 2864                         NaN
# 2865                         NaN
# 2866                         NaN
# 2867                         NaN
# 2868                         NaN
# 2869             and between new
# 2870                         NaN
# 2871                         NaN
# 2872             Another she the
# 2873                         NaN
# Name: 3, Length: 2874, dtype: object)
# content:
# (4, 0                          NaN
# 1                          NaN
# 2                          NaN
# 3          instead idleness to
# 4       the instead addressing
# 5                          NaN
# 6         accuracy set opening
# 7                          NaN
# 8                          NaN
# 9                    it the is
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16             the intimate in
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                 of The lean
# 23                me closer of
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28           pleasure or place
# 29                         NaN
#                  ...
# 2844                       NaN
# 2845                       NaN
# 2846                       NaN
# 2847                       NaN
# 2848                       NaN
# 2849                       NaN
# 2850                       NaN
# 2851                       NaN
# 2852                       NaN
# 2853                one the on
# 2854                       NaN
# 2855                       NaN
# 2856                       NaN
# 2857                       NaN
# 2858                       NaN
# 2859                       NaN
# 2860                       NaN
# 2861                       NaN
# 2862                       NaN
# 2863                my of dawn
# 2864                       NaN
# 2865                       NaN
# 2866                       NaN
# 2867                       NaN
# 2868                       NaN
# 2869                       NaN
# 2870                       NaN
# 2871                       NaN
# 2872           where takes the
# 2873                       NaN
# Name: 4, Length: 2874, dtype: object)

# %%
pd.DataFrame(gp)
# Out:
#                Unnamed: 0                               0  \
# 0                Ian Isla                me opening of of
# 1           Julian Isabel         brush rousing my truth:
# 2         Roman Valentina  melancholy One teacher writing
# 3              Diego Lyla         better cluster range at
# 4            Kaleb Lauren       em—after set poems warren
# 5              Bryce Isla          arrangement Or is dark
# 6        Christian Alaina           and Michael told gray
# 7           Jonah Destiny          is your opening lonely
# 8           Joseph Summer                   the the it of
# 9           Emmett Aurora              urgency to of lean
# 10         Eric Annabelle              teacher door of of
# 11         Cole Stephanie            are pleasure no lean
# 12           Kevin Melody        she encounter: there she
# 13             Silas Ella               One own ground at
# 14         Jackson Gianna   conventional but range silver
# 15          Thomas Peyton            over away near takes
# 16           Owen Adriana     that teacher em—after seems
# 17             Jake Ariel                   To the the be
# 18              Luke Mary              new Surely When is
# 19          Elijah Rachel       there for imagination her
# 20          Jake Scarlett             teacher may to told
# 21       Timothy Mckenzie  melancholy One teacher writing
# 22           Victor Kylee              intend is is music
# 23          Richard Avery               are me and closer
# 24       George Annabelle         between one now urgency
# 25             Colton Ava                 am no roses One
# 26          Angel Addison          looking dream now that
# 27           Jake Arianna               you but maybe way
# 28               Leo Ruby         urgency and opening the
# 29           Luke Kennedy              house of The logic
# ...                   ...                             ...
# 2844       Benjamin Grace            of One that language
# 2845         Mateo Payton               Surely is have in
# 2846          Xavier Lily               To her that there
# 2847         Bryan Evelyn             rooms and the where
# 2848       Ryker Julianna                 me of own logic
# 2849     Christian Claire             the that falling it
# 2850        Hayden Taylor            over away near takes
# 2851         Elias Aubrey            and ground she foggy
# 2852        Joel Savannah       where boulders You lonely
# 2853         Dominic Lily       to instead of familiarity
# 2854      Jayce Charlotte               joy When or about
# 2855       Vincent Bailey               music but she the
# 2856     Gabriel Izabella                  it is When but
# 2857          Abel Hayden             now near When place
# 2858     Greyson Makenzie        pleasure You the falling
# 2859        Declan Brooke             rooms and the where
# 2860      Joseph Isabelle               the logic that is
# 2861       Wyatt Izabella       em—after set poems warren
# 2862         Abel Valeria        brush addressing but may
# 2863  Christian Elizabeth                 the Or of image
# 2864    Benjamin Savannah                will of only set
# 2865   Santiago Alexandra                of of to bangles
# 2866     Bradley Madeline               out but tea dream
# 2867         Aidan Willow                 is is color for
# 2868          Kaden Julia            instead place far is
# 2869           Aidan Ella               in there are that
# 2870      Angel Annabelle             towards an now that
# 2871          Eric Summer                will of only set
# 2872    Zachary Stephanie               the Surely no the
# 2873           Josiah Mya             the for you rousing
#
#                                       1                              2  \
# 0          or emtheem intend melancholy               of the may color
# 1                           no of my is      there music always-new to
# 2              person house cluster set                            NaN
# 3                  and ground where The               have or the gray
# 4                 of urgency color only           poems intend an then
# 5                      of dark of rooms                is keep for one
# 6                                   NaN                            NaN
# 7                        the the The to                is is color for
# 8                       to of there and  door imagination silver music
# 9                 the accuracy is color           and ground she foggy
# 10        music dream describe emThisem                            NaN
# 11                  then of roses there                 it and she are
# 12                 then Another you but                  is me that of
# 13           and familiarity teacher or             may silver its now
# 14        arrangement there brush there           Or idleness you over
# 15          now towards writing writing                            NaN
# 16                   urgency the far me                  the is of use
# 17                                  NaN                            NaN
# 18                                  NaN                            NaN
# 19                  of brush that range     instead cluster then where
# 20                      out door and on                            NaN
# 21                                  NaN                            NaN
# 22                                  NaN                            NaN
# 23                                  NaN                            NaN
# 24    accuracy the familiarity accuracy            then of roses there
# 25                                  NaN                            NaN
# 26                to about warren touch            boulders out and of
# 27                       me and she the                            NaN
# 28                                  NaN                            NaN
# 29                 gray One and teacher           person may that into
# ...                                 ...                            ...
# 2844                  am wordless of is       to place boulders always
# 2845                 new Surely When is                 it You out far
# 2846     cluster lonely depending rules         arrangement Or is dark
# 2847                  you but maybe way         boulders image who the
# 2848              between that into was          own emThisem where is
# 2849                                NaN                            NaN
# 2850                  of your When told              or of gray lonely
# 2851                of into Or radiance        of You emtheem emThisem
# 2852             there lean Another the             may silver its now
# 2853               dark Michael the use                            NaN
# 2854                      at she of the                            NaN
# 2855             boulders image who the            emthisem the is you
# 2856                  who is intend the              you the one foggy
# 2857                                NaN                            NaN
# 2858                 new Surely When is                            NaN
# 2859             emthisem color that is              intend is the the
# 2860                     the it over is         me logic always-new to
# 2861            place the small Michael     brush The radiant emThisem
# 2862              there far better only                            NaN
# 2863                                NaN                            NaN
# 2864               about emtheem for in                it music is you
# 2865        remembering emThisem in are                            NaN
# 2866                      the now of an                 that is The to
# 2867             looking the warren you         your Michael dream her
# 2868         the always-new One emtheem              you but maybe way
# 2869      depending radiance of teacher               away and the its
# 2870       or emtheem intend melancholy             only of in urgency
# 2871             is bangles where there              joy When or about
# 2872        arrangement opening from is         of boulders closer the
# 2873    The familiarity looking urgency         the are there pleasure
#
#                                   3                              4  \
# 0                  may about may is         there lean Another the
# 1       that teacher em—after seems               dark no of seems
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4         remembering One small one                 brush is is of
# 5             an is arrangement the            you for opening who
# 6                               NaN                            NaN
# 7        bangles Michael Another in                            NaN
# 8                               NaN                            NaN
# 9           my remembering it roses                            NaN
# 10                              NaN                            NaN
# 11               urgency to of lean                            NaN
# 12                              NaN                            NaN
# 13             person may that into        there no are melancholy
# 14      teacher boulders use better          that radiance of told
# 15                              NaN                            NaN
# 16                              NaN                            NaN
# 17                              NaN                            NaN
# 18                              NaN                            NaN
# 19                              NaN                            NaN
# 20                              NaN                            NaN
# 21                              NaN                            NaN
# 22                              NaN                            NaN
# 23                              NaN                            NaN
# 24                   the it over is            now near When place
# 25                              NaN                            NaN
# 26        Or language pleasure past            is the the intimate
# 27                              NaN                            NaN
# 28                              NaN                            NaN
# 29             music then way there                            NaN
# ...                             ...                            ...
# 2844  melancholy bangles you better           the accuracy are are
# 2845            then of roses there               of the may color
# 2846                   is is it the           lean is accuracy the
# 2847       Another of cluster dream                            NaN
# 2848         you me describe always         familiarity is way the
# 2849                            NaN                            NaN
# 2850           only on accuracy are              lean You then she
# 2851               now and seems of         then now opening color
# 2852                            NaN                            NaN
# 2853                            NaN                            NaN
# 2854                            NaN                            NaN
# 2855        my remembering it roses       what your lonely Michael
# 2856             only of in urgency      to instead of familiarity
# 2857                            NaN                            NaN
# 2858                            NaN                            NaN
# 2859              dawn of there joy  door imagination silver music
# 2860             away no Surely the                out door and on
# 2861        brush the near Heizerem  arrangement there brush there
# 2862                            NaN                            NaN
# 2863                            NaN                            NaN
# 2864            you for opening who        there from emthisem her
# 2865                            NaN                            NaN
# 2866                            NaN                            NaN
# 2867             out the of cluster                dawn an now you
# 2868                            NaN                            NaN
# 2869       person house cluster set                            NaN
# 2870                            NaN                            NaN
# 2871                  the now of an                            NaN
# 2872                            NaN                            NaN
# 2873              One own ground at                            NaN
#
#                                5
# 0                            NaN
# 1        will talking the truth:
# 2                            NaN
# 3                            NaN
# 4                    of it it am
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# ...                          ...
# 2844  instead cluster then where
# 2845                         NaN
# 2846    pleasure You the falling
# 2847                         NaN
# 2848                         NaN
# 2849                         NaN
# 2850                         NaN
# 2851                         NaN
# 2852                         NaN
# 2853                         NaN
# 2854                         NaN
# 2855                         NaN
# 2856                         NaN
# 2857                         NaN
# 2858                         NaN
# 2859              for the to the
# 2860             what and the in
# 2861                         NaN
# 2862                         NaN
# 2863                         NaN
# 2864                         NaN
# 2865                         NaN
# 2866                         NaN
# 2867            now am told told
# 2868                         NaN
# 2869                         NaN
# 2870                         NaN
# 2871                         NaN
# 2872                         NaN
# 2873                         NaN
#
# [2874 rows x 7 columns]

# %%
pd.DataFrame(gs)
# Out:
#                Unnamed: 0                    0                1  \
# 0                Ian Isla           Maybe When            of of
# 1           Julian Isabel                  NaN              NaN
# 2         Roman Valentina                of of              NaN
# 3              Diego Lyla                  NaN              NaN
# 4            Kaleb Lauren              am door       dawn Maybe
# 5              Bryce Isla              am door          that to
# 6        Christian Alaina         of depending        better of
# 7           Jonah Destiny         color lonely     bangles that
# 8           Joseph Summer         bangles that     color lonely
# 9           Emmett Aurora                of of         from the
# 10         Eric Annabelle              am door       was Surely
# 11         Cole Stephanie         towards over        the touch
# 12           Kevin Melody              that to  over addressing
# 13             Silas Ella              gray me              NaN
# 14         Jackson Gianna                is of         from the
# 15          Thomas Peyton                  NaN              NaN
# 16           Owen Adriana         bangles that          am door
# 17             Jake Ariel           was Surely              NaN
# 18              Luke Mary             from the              NaN
# 19          Elijah Rachel              am door              NaN
# 20          Jake Scarlett         bangles that              NaN
# 21       Timothy Mckenzie           was Surely        better of
# 22           Victor Kylee                  NaN              NaN
# 23          Richard Avery            better of        better of
# 24       George Annabelle            better of     bangles that
# 25             Colton Ava              am door  over addressing
# 26          Angel Addison           Maybe When              NaN
# 27           Jake Arianna           Maybe When        the touch
# 28               Leo Ruby         color lonely              NaN
# 29           Luke Kennedy             or front     of depending
# ...                   ...                  ...              ...
# 2844       Benjamin Grace              that to            of of
# 2845         Mateo Payton             from the            of of
# 2846          Xavier Lily      over addressing     color lonely
# 2847         Bryan Evelyn                  NaN              NaN
# 2848       Ryker Julianna         of depending         or front
# 2849     Christian Claire             or front          that to
# 2850        Hayden Taylor                  NaN              NaN
# 2851         Elias Aubrey                  NaN              NaN
# 2852        Joel Savannah           dawn Maybe          that to
# 2853         Dominic Lily             from the              NaN
# 2854      Jayce Charlotte      over addressing     of depending
# 2855       Vincent Bailey           Maybe When        better of
# 2856     Gabriel Izabella      over addressing            is of
# 2857          Abel Hayden             or front     color lonely
# 2858     Greyson Makenzie  melancholy reaching          that to
# 2859        Declan Brooke            better of         or front
# 2860      Joseph Isabelle           One silver  over addressing
# 2861       Wyatt Izabella                of of         from the
# 2862         Abel Valeria            better of  over addressing
# 2863  Christian Elizabeth                  NaN              NaN
# 2864    Benjamin Savannah                  NaN              NaN
# 2865   Santiago Alexandra                  NaN              NaN
# 2866     Bradley Madeline         bangles that              NaN
# 2867         Aidan Willow              that to         or front
# 2868          Kaden Julia                  NaN              NaN
# 2869           Aidan Ella                of of            of of
# 2870      Angel Annabelle                is of        better of
# 2871          Eric Summer             or front         from the
# 2872    Zachary Stephanie           is Another        the touch
# 2873           Josiah Mya                  NaN              NaN
#
#                     2                3
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4             that to       is Another
# 5     over addressing              NaN
# 6          Maybe When              NaN
# 7                 NaN              NaN
# 8            from the              NaN
# 9                 NaN              NaN
# 10         was Surely         only who
# 11            that to              NaN
# 12                NaN              NaN
# 13                NaN              NaN
# 14           only who     bangles that
# 15                NaN              NaN
# 16       of depending     of depending
# 17                NaN              NaN
# 18                NaN              NaN
# 19                NaN              NaN
# 20                NaN              NaN
# 21                NaN              NaN
# 22                NaN              NaN
# 23         was Surely              NaN
# 24       bangles that              NaN
# 25          better of         from the
# 26                NaN              NaN
# 27          the touch              NaN
# 28                NaN              NaN
# 29                NaN              NaN
# ...               ...              ...
# 2844              NaN              NaN
# 2845              NaN              NaN
# 2846          that to              NaN
# 2847              NaN              NaN
# 2848          that to              NaN
# 2849        the touch       was Surely
# 2850              NaN              NaN
# 2851              NaN              NaN
# 2852              NaN              NaN
# 2853              NaN              NaN
# 2854              NaN              NaN
# 2855              NaN              NaN
# 2856           be the              NaN
# 2857          that to              NaN
# 2858       was Surely              NaN
# 2859              NaN              NaN
# 2860            is of          am door
# 2861            of of              NaN
# 2862              NaN              NaN
# 2863              NaN              NaN
# 2864              NaN              NaN
# 2865              NaN              NaN
# 2866              NaN              NaN
# 2867         only who              NaN
# 2868              NaN              NaN
# 2869         from the     color lonely
# 2870              NaN              NaN
# 2871          am door       was Surely
# 2872            of of  over addressing
# 2873              NaN              NaN
#
# [2874 rows x 5 columns]

# %%
type(gc)
# Out:
# pandas.core.frame.DataFrame
